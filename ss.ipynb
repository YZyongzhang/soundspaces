# %%
# %%capture notebook_ouput
# test env
import sys
sys.argv = [sys.argv[0]]
from config import config
from env.v0d0 import Env
import torch
import pickle
import numpy as np
import habitat_sim
from habitat.utils.visualizations import maps
import random
from utils import *
env = Env(config)
env.reset()

# %%
# test database
import sys
sys.argv = [sys.argv[0]]
from config import agent_config
import pickle , lmdb
class test_lmbd:
    def __init__(self , agent_config , level):
        self.database_path = agent_config.DATABASE_DIR + 'shffule_mutienv_data_combinencode_level/' + f'combinencode_level_{level}'
